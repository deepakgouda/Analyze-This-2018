# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train=pd.read_csv("./Data/Training_dataset_Original.csv", low_memory=False)

# %%
def replace_nan(data):
    data = data.replace("nan", np.nan)
    data = data.replace("missing", np.nan)
    data = data.replace("na", np.nan)
    return data

# %%
train = replace_nan(train)

# %%
def fill_data(data):
    data['mvar47'] = data['mvar47'] == 'C'
    data = data.astype(dtype='float64')
    data = data.fillna(data.median())
#     data = data.fillna(data.mean())
    return data

# %%
train = fill_data(train)

# %%
train.head()
# Out:
#    application_key   mvar1   mvar2  mvar3  mvar4  mvar5   mvar6    mvar7  \
# 0         230032.0  1696.0  1.6541  0.000    0.0    0.0     0.0   6015.0
# 1         230033.0  1846.0  0.8095  0.000    0.0    0.0   102.0   7532.0
# 2         230034.0  1745.0  0.4001  0.000    0.0    0.0   297.0   2536.0
# 3         230035.0  1739.0  0.2193  0.000    0.0    0.0  1982.0  26440.0
# 4         230036.0  1787.0  0.0118  0.225    0.0    0.0  5451.0   5494.0
#
#     mvar8    mvar9     ...       mvar39   mvar40   mvar41   mvar42  mvar43  \
# 0   322.0  40369.0     ...          1.0   73.780  82.5470  0.08696    10.0
# 1  3171.0  18234.0     ...          0.0   99.129  78.8835  0.00000    13.0
# 2  2478.0  14171.0     ...          0.0  100.000  29.2900  0.00000     1.0
# 3  4955.0  20316.0     ...          0.0   96.272  78.8835  0.15385     3.0
# 4  5494.0   7987.0     ...          0.0  115.019  78.8835  0.00000     1.0
#
#     mvar44  mvar45  mvar46  mvar47  default_ind
# ...

# %%
for i in range(1, 48):
    X = train['mvar'+str(i)].values
    # X[:5]

    bins=100
    freq=np.histogram(X, bins=bins)
    # freq[:]

    x=np.delete(freq[1], bins)
    y=freq[0]
    # y=freq[0]/float(len(X))

    # y
    t = "mvar"+str(i)
    plt.title(t+" mean = %f median = %f"%(train[t].mean(), train[t].median()))
    plt.bar(x, y, width=((max(x) - min(x))/50.0))
    plt.show()

# %%
 'mvar2', 'mvar3', 'mvar4', 'mvar5', 'mvar6', 'mvar7', 'mvar8', 'mvar9', 'mvar10', 'mvar11', 'mvar12', 'mvar13', 'mvar14', 'mvar15', 'mvar16', 'mvar17', 'mvar18', 'mvar19', 'mvar20', 'mvar32', 'mvar33', 'mvar34', 'mvar35', 'mvar36', 'mvar47', 'mvar39', 'mvar42', 'mvar43', 'mvar44', 'mvar45', 'mvar46'
