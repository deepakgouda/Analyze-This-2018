# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./Data/Training_dataset_Small.csv', low_memory=False)

# %%
data = data.replace("nan", np.nan)
data = data.replace("missing", np.nan)
data = data.replace("na", np.nan)

# %%
data = data.fillna(data.median())

# %%
X = data['mvar3']
Y = data['mvar5']
plt.plot(X, Y)
plt.show()

# %%
X = data['mvar3']
Y = data['mvar4']
X = X.astype('str')
Y = Y.astype('str')
plt.plot(X, Y)
plt.show()

# %%
X = data['mvar4']
Y = data['mvar5']
plt.plot(X, Y)
plt.show()

# %%
X = data['mvar7']
Y = data['mvar8']
X = X.astype('str')
Y = Y.astype('str')
plt.plot(X, Y)
plt.show()

# %%
X = data['mvar22']
Y = data['mvar23']
X = X.astype('str')
Y = Y.astype('str')
plt.plot(X, Y)
plt.show()

# %%
X = data['mvar45']
Y = data['mvar46']
X = X.astype('str')
Y = Y.astype('str')
plt.plot(X, Y)
plt.show()

# %%
X = data['mvar40']
Y = data['mvar41']
X = X.astype('str')
Y = Y.astype('str')
plt.plot(X, Y)
plt.show()

# %%
X = data['mvar17']
Y = data['mvar18']
X = X.astype('str')
Y = Y.astype('str')
plt.plot(X, Y)
plt.show()

# %%
X = data['mvar19']
Y = data['mvar20']
X = X.astype('str')
Y = Y.astype('str')
plt.plot(X, Y)
plt.show()

# %%
X = data['mvar13']
Y = data['mvar14']
X = X.astype('str')
Y = Y.astype('str')
plt.plot(X, Y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-99-4d4b338d76ff> in <module>
#       4 Y = Y.astype('str')
#       5 plt.plot(X, Y)
# ----> 6 plt.show()
#
# ~/.virtualenvs/DATA/lib/python3.5/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# ~/.virtualenvs/DATA/lib/python3.5/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/.virtualenvs/DATA/lib/python3.5/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
# ...

# %%
X = data['mvar14']
Y = data['mvar36']
X = X.astype('str')
Y = Y.astype('str')
plt.plot(X, Y)
plt.show()

# %%
X = data['mvar26']
Y = data['mvar27']
X = X.astype('str')
Y = Y.astype('str')
plt.plot(X, Y)
plt.show()

# %%
X = data['mvar37']
Y = data['mvar38']
X = X.astype('str')
Y = Y.astype('str')
plt.plot(X, Y)
plt.show()

# %%
def data_nan_row(data):
    total = data.isnull().sum(axis=1).sort_values(ascending=False)
    percent = (data.isnull().sum(axis=1)/data.isnull().count(axis=1)).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %%
missing = data_nan_row(data)

# %%
missing.values[2000]
# Out:
# array([13.        ,  0.26530612])

# %%
delrows = list((missing.index)[:2000])
len(delrows)
# Out:
# 2000

# %%
data = data.drop(delrows)

# %%
data.shape
# Out:
# (8000, 49)
