# %%
import numpy as np
import missingno as mn
import pandas as pd

# %%
data = pd.read_csv('./Data/Training_dataset_Small.csv')

# %%
mn.dendrogram(data)

# %%
mn.heatmap(data)

# %%
mn.bar(data)

# %%
mn.matrix(data)

# %%
data.describe()
# Out:
#        application_key        mvar2        mvar3        mvar4        mvar5  \
# count      10000.00000  9213.000000  9943.000000  9943.000000  9943.000000
# mean      235031.50000     0.893653     4.847383     0.371741     1.049535
# std         2886.89568     1.282640    10.512331     1.475365     5.917381
# min       230032.00000     0.000000     0.000000     0.000000     0.000000
# 25%       232531.75000     0.108300     0.000000     0.000000     0.000000
# 50%       235031.50000     0.421100     0.173000     0.000000     0.000000
# 75%       237531.25000     1.186700     5.457000     0.000000     0.000000
# max       240031.00000    19.986500   166.341000    20.248000   165.492000
#
#              mvar14        mvar19       mvar21        mvar22        mvar23  \
# count  1.000000e+04  10000.000000  7218.000000   6190.000000   4706.000000
# mean   2.543852e+05      0.859900    55.456264   4196.105360   4186.566547
# ...
