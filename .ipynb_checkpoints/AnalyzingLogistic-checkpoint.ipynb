# %%
import numpy as np
import missingno as mn
import pandas as pd

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA

# %%
# data = pd.read_csv('./Data/Training_dataset_Small.csv')
data = pd.read_csv('./Data/Training_dataset_Original.csv', low_memory=False)

# %%
data.head()
# Out:
#    application_key mvar1   mvar2  mvar3  mvar4  mvar5    mvar6  mvar7  \
# 0           230032  1696  1.6541  0.000    0.0    0.0        0   6015
# 1           230033  1846  0.8095  0.000    0.0    0.0      102   7532
# 2           230034  1745  0.4001  0.000    0.0    0.0  missing   2536
# 3           230035  1739  0.2193  0.000    0.0    0.0     1982  26440
# 4           230036  1787  0.0118  0.225    0.0    0.0     5451   5494
#
#      mvar8    mvar9     ...     mvar39   mvar40   mvar41   mvar42  mvar43  \
# 0      322    40369     ...          1    73.78   82.547  0.08696      10
# 1     3171    18234     ...          0   99.129  missing        0      13
# 2  missing  missing     ...          0  missing    29.29        0       1
# 3     4955    20316     ...          0   96.272  missing  0.15385       3
# 4     5494     7987     ...          0  115.019  missing        0       1
#
#     mvar44 mvar45 mvar46 mvar47 default_ind
# 0  0.63899     na      0      C           0
# 1  0.63836     na     na      L           1
# 2  1.00000     na      0      C           1
# 3  0.53241      0      0      L           0
# 4  0.92665     na     na      L           0
#
# [5 rows x 49 columns]

# %%
data = data.replace("nan", np.nan)
data = data.replace("missing", np.nan)
data = data.replace("na", np.nan)

# %%
def data_nan_row(data):
    total = data.isnull().sum(axis=1).sort_values(ascending=False)
    percent = (data.isnull().sum(axis=1)/data.isnull().count(axis=1)).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %%
missing = data_nan_row(data)

# %%
missing.values[17017]
# Out:
# array([12.        ,  0.24489796])

# %%
delrows = list((missing.index)[:17017])
data = data.drop(delrows)
data.shape
# Out:
# (62983, 49)

# %%
data_nan_row(data)
# Out:
#        Total   Percent
# 31223     12  0.244898
# 58019     12  0.244898
# 60984     12  0.244898
# 42167     12  0.244898
# 8577      12  0.244898
# 40428     12  0.244898
# 37610     12  0.244898
# 43824     12  0.244898
# 61002     12  0.244898
# 12821     12  0.244898
# 5952      12  0.244898
# 54978     12  0.244898
# 51618     12  0.244898
# 61041     12  0.244898
# 40403     12  0.244898
# 72430     12  0.244898
# 33044     12  0.244898
# 22340     12  0.244898
# 9830      12  0.244898
# 40395     12  0.244898
# 11284     12  0.244898
# 67160     12  0.244898
# 55017     12  0.244898
# 17874     12  0.244898
# 42137     12  0.244898
# 42143     12  0.244898
# 9816      12  0.244898
# 8616      12  0.244898
# 78826     12  0.244898
# 70357     12  0.244898
# ...      ...       ...
# 78870      0  0.000000
# 38483      0  0.000000
# 39405      0  0.000000
# 56412      0  0.000000
# 21270      0  0.000000
# 27312      0  0.000000
# 56537      0  0.000000
# 72963      0  0.000000
# 33217      0  0.000000
# 62770      0  0.000000
# 3260       0  0.000000
# 62789      0  0.000000
# 58218      0  0.000000
# 71559      0  0.000000
# 56650      0  0.000000
# 26673      0  0.000000
# 52190      0  0.000000
# 23341      0  0.000000
# 13583      0  0.000000
# 41606      0  0.000000
# 60242      0  0.000000
# 25866      0  0.000000
# 52072      0  0.000000
# 33979      0  0.000000
# 65525      0  0.000000
# 15305      0  0.000000
# 69616      0  0.000000
# 4242       0  0.000000
# 9727       0  0.000000
# 71918      0  0.000000
#
# [62983 rows x 2 columns]

# %%
mn.heatmap(data)

# %%
# np.set_printoptions(threshold=np.inf)
data.describe(include='all')
# Out:
#         application_key  mvar1         mvar2         mvar3         mvar4  \
# count      62983.000000  62777  59273.000000  62983.000000  62983.000000
# unique              NaN    447           NaN           NaN           NaN
# top                 NaN   1736           NaN           NaN           NaN
# freq                NaN    454           NaN           NaN           NaN
# mean      270081.583919    NaN      1.089034      3.874495      0.337246
# std        23088.354269    NaN      1.632804      8.949366      1.455814
# min       230032.000000    NaN      0.000000      0.000000      0.000000
# 25%       250083.500000    NaN      0.131500      0.000000      0.000000
# 50%       270102.000000    NaN      0.520100      0.000000      0.000000
# 75%       290095.500000    NaN      1.426800      3.394000      0.000000
# max       310031.000000    NaN     36.030100    173.439000     50.929000
#
#                mvar5  mvar6  mvar7  mvar8  mvar9      ...      mvar39 mvar40  \
# count   62983.000000  60428  62941  60428  61832      ...       62983  13838
# unique           NaN   7014  27483  15609  28792      ...          14  11289
# top              NaN      0      0      0    297      ...           0    100
# freq             NaN  10685   1014   2617    740      ...       58819   1590
# mean        0.649281    NaN    NaN    NaN    NaN      ...         NaN    NaN
# std         4.250208    NaN    NaN    NaN    NaN      ...         NaN    NaN
# min         0.000000    NaN    NaN    NaN    NaN      ...         NaN    NaN
# 25%         0.000000    NaN    NaN    NaN    NaN      ...         NaN    NaN
# 50%         0.000000    NaN    NaN    NaN    NaN      ...         NaN    NaN
# 75%         0.000000    NaN    NaN    NaN    NaN      ...         NaN    NaN
# max       173.439000    NaN    NaN    NaN    NaN      ...         NaN    NaN
#
#        mvar41 mvar42  mvar43        mvar44 mvar45 mvar46 mvar47   default_ind
# count   22781  62487   62959  62298.000000  31941  48363  62983  62983.000000
# unique  17755    970      59           NaN      6      7      2           NaN
# top       100      0       3           NaN      0      0      C           NaN
# freq      553  23488    5498           NaN  30288  45736  39142           NaN
# mean      NaN    NaN     NaN      0.690880    NaN    NaN    NaN      0.201134
# std       NaN    NaN     NaN      0.239380    NaN    NaN    NaN      0.400851
# min       NaN    NaN     NaN      0.060660    NaN    NaN    NaN      0.000000
# 25%       NaN    NaN     NaN      0.506780    NaN    NaN    NaN      0.000000
# 50%       NaN    NaN     NaN      0.714925    NaN    NaN    NaN      0.000000
# 75%       NaN    NaN     NaN      0.914180    NaN    NaN    NaN      0.000000
# max       NaN    NaN     NaN      1.000000    NaN    NaN    NaN      1.000000
#
# [11 rows x 49 columns]

# %%
def draw_missing_data_table(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %%
(draw_missing_data_table(data))[:12]
# Out:
#         Total   Percent
# mvar40  49145  0.780290
# mvar31  44573  0.707699
# mvar11  40859  0.648731
# mvar41  40202  0.638299
# mvar45  31042  0.492863
# mvar30  25513  0.405078
# mvar23  23882  0.379182
# mvar15  23377  0.371164
# mvar35  17499  0.277837
# mvar46  14620  0.232126
# mvar22  13572  0.215487
# mvar21   6140  0.097487

# %%
def refine(data):
    data.drop('mvar40', axis=1, inplace=True)
    data.drop('mvar31', axis=1, inplace=True)
    data.drop('mvar11', axis=1, inplace=True)
    data.drop('mvar41', axis=1, inplace=True)
    data.drop('mvar45', axis=1, inplace=True)
    data.drop('mvar30', axis=1, inplace=True)
    data.drop('mvar23', axis=1, inplace=True)
    data.drop('mvar15', axis=1, inplace=True)    
    
#     data.drop('mvar35', axis=1, inplace=True)
#     data.drop('mvar22', axis=1, inplace=True)
    return data

# %%
def preprocess(data):
    data = refine(data)
#     mn.dendrogram(data)
#     mn.heatmap(data)
#     mn.bar(data)
#     mn.matrix(data)
    # data.mean(skipna = True)
    # data['mvar1'].mean(skipna = True)
    # data.median()
    data = data.fillna(data.median())
    data['mvar47'] = data['mvar47'] == 'C'
#     data['mvar47'].head()
    return data

# %%
data = preprocess(data)

# %%
X = data[data.loc[:, data.columns != 'default_ind'].columns]
Y = data['default_ind']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=1)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (50386, 40)
# (12597, 40)
# (50386,)
# (12597,)

# %%
print(X_train.head())
# Out:
#        application_key mvar1   mvar2  mvar3  mvar4  mvar5 mvar6   mvar7  \
# 30634           260666  1899  0.0327  0.000  0.000    0.0  2478  208110
# 57224           287256  1777  0.6776  0.000  0.000    0.0    36   15250
# 310             230342  1917  0.1304  0.000  0.000    0.0   496   19820
# 7022            237054  1627  2.7008  1.930  0.000    0.0     0     717
# 69118           299150  1668  0.0000  6.853  6.853    0.0    37   17739
#
#        mvar8   mvar9   ...   mvar35 mvar36 mvar37  mvar38 mvar39   mvar42  \
# 30634  23784  147926   ...        0      5      1       7      0        0
# 57224   3310   65951   ...        0     11      7      12      0    0.125
# 310    19820   61443   ...        0      2      8       1      0        0
# 7022       0     460   ...        1      5      0       4      0        1
# 69118  17739    1387   ...        0     30      0      25      0  0.96875
#
#       mvar43   mvar44 mvar46  mvar47
# 30634     21  0.96923      0   False
# 57224     15  0.65294      0    True
# 310        7  0.55142      0   False
# 7022       1  0.97043      0   False
# 69118      1  1.00000      1    True
#
# [5 rows x 40 columns]

# %%
lr = LogisticRegression(solver='warn', max_iter = 100)
lr.fit(X_train, Y_train)
print("Done")
# Out:
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Done
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
scores = cross_val_score(lr, X_train, Y_train, cv=10)
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# CV accuracy: 0.814 +/- 0.004

# %%
scores = cross_val_score(lr, X_test, Y_test, cv=10)
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/epsilon/.virtualenvs/DATA/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# CV accuracy: 0.817 +/- 0.009

# %%
# np.set_printoptions(threshold=np.inf)

# %%
# type(predict)
# X_test.head()

# %%
lb = pd.read_csv('./Data/Leaderboard_dataset.csv', low_memory=False)

# %%
lb = lb.replace("nan", np.nan)
lb = lb.replace("missing", np.nan)
lb = lb.replace("na", np.nan)

# %%
print(lb.shape)
# Out:
# (25000, 48)

# %%
lb = preprocess(lb)
predict = lr.predict(lb)

# %%
predict = pd.DataFrame(predict)
# print(predict.head())
print(predict.shape)
# Out:
# (25000, 1)

# %%
np.set_printoptions(threshold=np.inf)
print(predict)
# Out:
#        0
# 0      0
# 1      0
# 2      0
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      0
# 9      0
# 10     0
# 11     1
# 12     0
# 13     1
# 14     0
# 15     1
# 16     0
# 17     0
# 18     0
# 19     0
# 20     0
# 21     0
# 22     0
# 23     1
# 24     1
# 25     0
# 26     0
# 27     0
# 28     1
# 29     0
# ...   ..
# 24970  1
# 24971  0
# 24972  1
# 24973  1
# 24974  1
# 24975  0
# 24976  0
# 24977  0
# 24978  1
# 24979  1
# 24980  0
# 24981  1
# 24982  1
# 24983  0
# 24984  0
# 24985  0
# 24986  1
# 24987  1
# 24988  1
# 24989  1
# 24990  1
# 24991  0
# 24992  1
# 24993  1
# 24994  0
# 24995  0
# 24996  0
# 24997  1
# 24998  0
# 24999  0
#
# [25000 rows x 1 columns]

# %%
key = pd.DataFrame(lb['application_key'])
# key = key.values
print(key.shape)
# Out:
# (25000, 1)

# %%
pred = pd.DataFrame()
pred['application_key'] = lb['application_key']
pred['default_ind'] = predict
print(pred.head())
# Out:
#    application_key  default_ind
# 0           350053            0
# 1           350054            0
# 2           350055            0
# 3           350056            1
# 4           350057            0

# %%
pred.to_csv("Analyzing_IITGuwahati_1.csv")
